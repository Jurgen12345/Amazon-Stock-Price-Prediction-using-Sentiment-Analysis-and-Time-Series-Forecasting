# %%
from google.colab import drive, files
drive.mount('/content/gdrive/')

import os
PROJECT_FOLDER = "/content/gdrive/MyDrive/Colab Notebooks/Thesis/Data Scraping-Preprocessing"
os.chdir(PROJECT_FOLDER)
print("Current dir: ", os.getcwd())
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# Current dir:  /content/gdrive/MyDrive/Colab Notebooks/Thesis/Data Scraping-Preprocessing

# %%
# !pip install yfinance

# %%
import yfinance as yf
ticker = "AMZN"
amzn_data = yf.download(ticker,start = '2021-05-10', end='2025-05-10')
amzn_data.to_csv("AMAZON_HISTORICAL_DATA.csv")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AMZN        AMZN        AMZN        AMZN       AMZN
# Date
# 2021-05-10  159.524506  164.149994  159.500000  164.115997  116772000
# 2021-05-11  161.195496  161.899994  156.368500  156.813995   92396000
# 2021-05-12  157.597000  160.397003  156.654999  159.250000   98728000
# 2021-05-13  158.073502  160.192001  156.649994  159.273499   67018000
# 2021-05-14  161.145004  161.442993  159.149994  159.278000   66500000
